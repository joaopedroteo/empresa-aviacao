# %% [markdown]
# ### Alunos:
# Gabriel Ribeiro Oliveira
#
# João Pedro Teodoro Silva
#
# Livro: Pesquisa Operacional - 2 Ediçao

# %% [markdown]
# ## Exercício 2.13 - Problema: Tratamento de Esgoto
#
# Os esgotos de três cidades, A, B, e C, depois de passarem por uma estação de tratamento, são jogados num rio, conforme a figura seguinte. Os esgotos das três cidades produzem  quantidades  diárias  de  poluente,  respectivamente,  PA,  PB  e  PC  toneladas.
#
# O tratamento  do  esgoto  pode  reduzir  a  quantidade  de  poluentes  em  até  90%. Essa  redução  é denominada  eficiência  da  estação  de  tratamento  e  o  custo  da  estação i  é  diretamente proporcional à sua eficiência.
#
# Por outro lado, devido à ação bioquímica (aeração, etc.), no final de cada trecho AB e BC do rio, a quantidade de poluentes é reduzida em 10% e 20% respectivamente.
#
# Quais são as eficiências das estações de tratamento, de modo que em qualquer ponto do rio a quantidade de poluentes não ultrapasse P toneladas e o custo das estações de tratamento seja mínimo? Escreva um modelo de otimização linear para este problema.

# %% [markdown]
# ### Dados:
# - $M = [A, B, C]$, conjunto de cidades
#
# - $P_{A}, P_{B}, P_{C}$, toneladas de poluentes
# - $C_{i}$, custo da estação da cidade $i$
# - $P$, máximo de poluentes permitido
#
# ### Variável
# - $E_{i}$, Eficiência da estação da cidade $i$
# Os esgotos de três cidades, A, B, e C, depois de passarem por uma estação de tratamento, são jogados num rio, conforme a figura seguinte. Os esgotos das três cidades produzem  quantidades  diárias  de  poluente,  respectivamente,  PA,  PB  e  PC  toneladas.
# ### Função
# \begin{equation}
#     \min \sum_{i \in M} C_{i} * E_{i}
# \end{equation}
#
# ### Restrições
# - $P_{A} * E_{A} \le P$
#
# - $(P_{A} * E_{A}) * 0.9 + P_{B} * E_{B} \le P$
#
# - $((P_{A} * E_{A}) * 0.9 + P_{B} * E_{B}) * 0.8 + P_{C} * E_{C} \le P$
#
# - $E_{i} \le 0.9, \forall i \in E$
#
# - $E_{i} \ge 0, \forall i \in E$

# %% [markdown]
# ## Exercício 2.14 - Problema: Corte de laminas
#
# Considere  o  problema  de  corte  de  bobinas  na  seção  2.2  e  o  modelo  de otimização linear em (2.19).
#
# A) Suponha  que  haja  uma  tolerância τi na  demanda  do  item i,  isto  é,  os  clientes  aceitam qualquer quantidade do item i no intervalo [(1−τi)bi   (1+τi)bi]. Reformule o modelo (2.19) para considerar esta tolerância.
#
# B) Escreva um modelo para o exemplo 2.10, considerando uma tolerância de τi = 0,05 (isto é, ±5%, de modo que a demanda do item de tamanho l1 = 40 é qualquer valor entre 4,75 e 5,25 toneladas).

# %% [markdown]
# ### Dados:
# - $N$, Padrões de cortes
# - $M$, Tipos de cortes
# - $L = {l_0 ... l_m}$, Tamanhos para cortes da lamina
# - $b = {b_1 ... b_m}$, Quantidade de cortes para cada tamanho
# - $a_{ij}$, Número de itens tipo $i$ no padrão de corte $j$
#
#
# ### Variável
# - $y_i$, Quantidade cortada segundo o padrão de corte $i$
#
# ### Função
# \begin{equation}
#     \min G(y_1, ..., y_n) = \sum_{i \in N} y_i
# \end{equation}
#
# ### Restrições exercício A
# - \begin{equation}
#     {\begin{bmatrix}
#         \frac{l_1}{L}*a_{11} \\
#         \frac{l_2}{L}*a_{21} \\
#         \vdots \\
#         \frac{l_m}{L}*a_{m1} \
#     \end{bmatrix}}\
#     y_1 + \cdots + \
#     {\begin{bmatrix}
#         \frac{l_1}{L}*a_{1n} \\
#         \frac{l_2}{L}*a_{2n} \\
#         \vdots \\
#         \frac{l_m}{L}*a_{mn} \
#     \end{bmatrix}} \
#     y_n \le \
#     {\begin{bmatrix}
#         (1 + \tau) b_1 \\
#         (1 + \tau) b_2 \\
#         \vdots \\
#         (1 + \tau) b_m
#         \
#     \end{bmatrix}} \
# \end{equation}
#
# - \begin{equation}
#     {\begin{bmatrix}
#         \frac{l_1}{L}*a_{11} \\
#         \frac{l_2}{L}*a_{21} \\
#         \vdots \\
#         \frac{l_m}{L}*a_{m1} \
#     \end{bmatrix}}\
#     y_1 + \cdots + \
#     {\begin{bmatrix}
#         \frac{l_1}{L}*a_{1n} \\
#         \frac{l_2}{L}*a_{2n} \\
#         \vdots \\
#         \frac{l_m}{L}*a_{mn} \
#     \end{bmatrix}} \
#     y_n \ge \
#     {\begin{bmatrix}
#         (1 - \tau) b_1 \\
#         (1 - \tau) b_2 \\
#         \vdots \\
#         (1 - \tau) b_m
#         \
#     \end{bmatrix}} \
# \end{equation}
# - $y_{i} \ge 0, \forall i \in N$

# %% [markdown]
# ### Exercício B)

# %% [markdown]
# - \begin{equation}
#     \begin{matrix}
#         \begin{bmatrix}
#             \dfrac{40}{400} a_{11} \\ \dfrac{45}{400} a_{21} \\ \dfrac{55}{400} a_{31} \\ \dfrac{60}{400} a_{41} \\
#         \end{bmatrix}
#         y_{1} +
#         \begin{bmatrix}
#             \dfrac{40}{400} a_{12} \\ \dfrac{45}{400} a_{22} \\ \dfrac{55}{400} a_{32} \\ \dfrac{60}{400} a_{42} \\
#         \end{bmatrix}
#         y_{2} +
#         \begin{bmatrix}
#             \dfrac{40}{400} a_{13} \\ \dfrac{45}{400} a_{23} \\ \dfrac{55}{400} a_{33} \\ \dfrac{60}{400} a_{43} \\
#         \end{bmatrix}
#         y_{3} +
#         \begin{bmatrix}
#             \dfrac{40}{400} a_{14} \\ \dfrac{45}{400} a_{24} \\ \dfrac{55}{400} a_{34} \\ \dfrac{60}{400} a_{44} \\
#         \end{bmatrix}
#         y_{4} \ge
#         \begin{bmatrix}
#             5 \\ 3,5 \\ 4 \\ 5 \\
#         \end{bmatrix}
#         (0,95)
#     \end{matrix}
# \end{equation}
#
# - \begin{equation}
#     \begin{matrix}
#         \begin{bmatrix}
#             \dfrac{40}{400} a_{11} \\ \dfrac{45}{400} a_{21} \\ \dfrac{55}{400} a_{31} \\ \dfrac{60}{400} a_{41} \\
#         \end{bmatrix}
#         y_{1} +
#         \begin{bmatrix}
#             \dfrac{40}{400} a_{12} \\ \dfrac{45}{400} a_{22} \\ \dfrac{55}{400} a_{32} \\ \dfrac{60}{400} a_{42} \\
#         \end{bmatrix}
#         y_{2} +
#         \begin{bmatrix}
#             \dfrac{40}{400} a_{13} \\ \dfrac{45}{400} a_{23} \\ \dfrac{55}{400} a_{33} \\ \dfrac{60}{400} a_{43} \\
#         \end{bmatrix}
#         y_{3} +
#         \begin{bmatrix}
#             \dfrac{40}{400} a_{14} \\ \dfrac{45}{400} a_{24} \\ \dfrac{55}{400} a_{34} \\ \dfrac{60}{400} a_{44} \\
#         \end{bmatrix}
#         y_{4} \le
#         \begin{bmatrix}
#             b_{1} \\ b_{2} \\ b_{3} \\ b_{4} \\
#         \end{bmatrix}
#         (1,05)
#     \end{matrix}
# \end{equation}
# - \begin{equation}
#     y_{1} \ge 0, \cdots, y_{n} \ge 0
# \end{equation}
